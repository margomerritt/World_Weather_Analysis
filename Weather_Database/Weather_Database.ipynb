# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 724

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")

    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]  
        city_weather_description = city_weather["weather"][0]["description"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

         
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | oksfjord
# Processing Record 3 of Set 1 | srednekolymsk
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | sinnar
# Processing Record 10 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 1 | preobrazheniye
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | victoria
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | cabo san lucas
# Processing Record 16 of Set 1 | talnakh
# Processing Record 17 of Set 1 | la ronge
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | hamilton
# Processing Record 20 of Set 1 | sandwick
# Processing Record 21 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 1 | nioro
# Processing Record 23 of Set 1 | aklavik
# Processing Record 24 of Set 1 | sao filipe
# Processing Record 25 of Set 1 | iqaluit
# Processing Record 26 of Set 1 | okhotsk
# Processing Record 27 of Set 1 | alice springs
# Processing Record 28 of Set 1 | salta
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | kastamonu
# Processing Record 31 of Set 1 | bambous virieux
# Processing Record 32 of Set 1 | zhezkazgan
# Processing Record 33 of Set 1 | komsomolskiy
# Processing Record 34 of Set 1 | ribeira grande
# Processing Record 35 of Set 1 | cayenne
# Processing Record 36 of Set 1 | winneba
# Processing Record 37 of Set 1 | arona
# Processing Record 38 of Set 1 | samarai
# Processing Record 39 of Set 1 | chuy
# Processing Record 40 of Set 1 | orlik
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 1 | leningradskiy
# Processing Record 44 of Set 1 | muyezerskiy
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | te anau
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 49 of Set 1 | chokurdakh
# Processing Record 50 of Set 1 | ilulissat
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | rio grande
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | katsuura
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | tuktoyaktuk
# Processing Record 8 of Set 2 | pisco
# Processing Record 9 of Set 2 | cidreira
# Processing Record 10 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | port hedland
# Processing Record 13 of Set 2 | shu
# Processing Record 14 of Set 2 | fasa
# Processing Record 15 of Set 2 | souillac
# Processing Record 16 of Set 2 | sorkjosen
# Processing Record 17 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | faanui
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | kampong chhnang
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | salalah
# Processing Record 24 of Set 2 | broken hill
# Processing Record 25 of Set 2 | nanortalik
# Processing Record 26 of Set 2 | bandarbeyla
# Processing Record 27 of Set 2 | port elizabeth
# Processing Record 28 of Set 2 | oschatz
# Processing Record 29 of Set 2 | lukovetskiy
# Processing Record 30 of Set 2 | puerto ayora
# Processing Record 31 of Set 2 | mogadishu
# Processing Record 32 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 2 | taunggyi
# Processing Record 34 of Set 2 | qaqortoq
# Processing Record 35 of Set 2 | kirkland lake
# Processing Record 36 of Set 2 | vila velha
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | nikolskoye
# Processing Record 39 of Set 2 | dafeng
# Processing Record 40 of Set 2 | port lincoln
# Processing Record 41 of Set 2 | adrar
# Processing Record 42 of Set 2 | hervey bay
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | vilhena
# Processing Record 45 of Set 2 | labytnangi
# Processing Record 46 of Set 2 | kaitangata
# Processing Record 47 of Set 2 | tutoia
# Processing Record 48 of Set 2 | cap malheureux
# Processing Record 49 of Set 2 | clevedon
# Processing Record 50 of Set 2 | airai
# Processing Record 1 of Set 3 | nova olimpia
# Processing Record 2 of Set 3 | whitehorse
# Processing Record 3 of Set 3 | sur
# Processing Record 4 of Set 3 | bathsheba
# Processing Record 5 of Set 3 | bar harbor
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | chumikan
# Processing Record 8 of Set 3 | kavieng
# Processing Record 9 of Set 3 | cabedelo
# Processing Record 10 of Set 3 | macusani
# Processing Record 11 of Set 3 | nouadhibou
# Processing Record 12 of Set 3 | viedma
# Processing Record 13 of Set 3 | matara
# Processing Record 14 of Set 3 | kirakira
# Processing Record 15 of Set 3 | namibe
# Processing Record 16 of Set 3 | vardo
# Processing Record 17 of Set 3 | peniche
# Processing Record 18 of Set 3 | bethel
# Processing Record 19 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 3 | torbay
# Processing Record 21 of Set 3 | saskylakh
# Processing Record 22 of Set 3 | tabas
# Processing Record 23 of Set 3 | alice town
# Processing Record 24 of Set 3 | bilma
# Processing Record 25 of Set 3 | san pedro
# Processing Record 26 of Set 3 | toktogul
# Processing Record 27 of Set 3 | cape town
# Processing Record 28 of Set 3 | bengkulu
# Processing Record 29 of Set 3 | kampot
# Processing Record 30 of Set 3 | mgachi
# Processing Record 31 of Set 3 | lososina
# Processing Record 32 of Set 3 | mgandu
# Processing Record 33 of Set 3 | jamestown
# Processing Record 34 of Set 3 | mahaicony
# City not found. Skipping...
# Processing Record 35 of Set 3 | hithadhoo
# Processing Record 36 of Set 3 | hermanus
# Processing Record 37 of Set 3 | waipawa
# Processing Record 38 of Set 3 | castro
# Processing Record 39 of Set 3 | solnechnyy
# Processing Record 40 of Set 3 | ahumada
# City not found. Skipping...
# Processing Record 41 of Set 3 | kosonsoy
# Processing Record 42 of Set 3 | mlonggo
# Processing Record 43 of Set 3 | severo-kurilsk
# Processing Record 44 of Set 3 | kapaa
# Processing Record 45 of Set 3 | tautira
# Processing Record 46 of Set 3 | immokalee
# Processing Record 47 of Set 3 | skibbereen
# Processing Record 48 of Set 3 | westport
# Processing Record 49 of Set 3 | dikson
# Processing Record 50 of Set 3 | saint george
# Processing Record 1 of Set 4 | saldanha
# Processing Record 2 of Set 4 | kupino
# Processing Record 3 of Set 4 | kodiak
# Processing Record 4 of Set 4 | aquin
# Processing Record 5 of Set 4 | plettenberg bay
# Processing Record 6 of Set 4 | saint-philippe
# Processing Record 7 of Set 4 | ngunguru
# Processing Record 8 of Set 4 | potenza
# Processing Record 9 of Set 4 | cleveland
# Processing Record 10 of Set 4 | lucera
# Processing Record 11 of Set 4 | angoche
# Processing Record 12 of Set 4 | sao joao da barra
# Processing Record 13 of Set 4 | chulym
# Processing Record 14 of Set 4 | sept-iles
# Processing Record 15 of Set 4 | tura
# Processing Record 16 of Set 4 | tromso
# Processing Record 17 of Set 4 | kloulklubed
# Processing Record 18 of Set 4 | carnarvon
# Processing Record 19 of Set 4 | klaksvik
# Processing Record 20 of Set 4 | port alfred
# Processing Record 21 of Set 4 | giehun
# Processing Record 22 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 4 | walvis bay
# Processing Record 24 of Set 4 | panzhihua
# Processing Record 25 of Set 4 | defiance
# Processing Record 26 of Set 4 | kaeo
# Processing Record 27 of Set 4 | xining
# Processing Record 28 of Set 4 | puerto quijarro
# Processing Record 29 of Set 4 | kutum
# Processing Record 30 of Set 4 | thompson
# Processing Record 31 of Set 4 | havoysund
# Processing Record 32 of Set 4 | hibbing
# Processing Record 33 of Set 4 | luderitz
# Processing Record 34 of Set 4 | los llanos de aridane
# Processing Record 35 of Set 4 | matelica
# Processing Record 36 of Set 4 | praia da vitoria
# Processing Record 37 of Set 4 | barrow
# Processing Record 38 of Set 4 | eqbaliyeh
# Processing Record 39 of Set 4 | yerky
# Processing Record 40 of Set 4 | blagoyevo
# Processing Record 41 of Set 4 | yunhe
# Processing Record 42 of Set 4 | caucaia
# Processing Record 43 of Set 4 | mount gambier
# Processing Record 44 of Set 4 | zhigansk
# Processing Record 45 of Set 4 | zemio
# Processing Record 46 of Set 4 | high level
# Processing Record 47 of Set 4 | yulara
# Processing Record 48 of Set 4 | sinjar
# Processing Record 49 of Set 4 | sungaipenuh
# Processing Record 50 of Set 4 | tiznit
# Processing Record 1 of Set 5 | montelibano
# Processing Record 2 of Set 5 | harper
# Processing Record 3 of Set 5 | narsaq
# Processing Record 4 of Set 5 | dalvik
# Processing Record 5 of Set 5 | nenjiang
# Processing Record 6 of Set 5 | karratha
# Processing Record 7 of Set 5 | lyuban
# Processing Record 8 of Set 5 | nishihara
# Processing Record 9 of Set 5 | chalchihuites
# Processing Record 10 of Set 5 | port augusta
# Processing Record 11 of Set 5 | moerai
# Processing Record 12 of Set 5 | sawakin
# Processing Record 13 of Set 5 | berlevag
# Processing Record 14 of Set 5 | san patricio
# Processing Record 15 of Set 5 | port hawkesbury
# Processing Record 16 of Set 5 | malindi
# Processing Record 17 of Set 5 | tiksi
# Processing Record 18 of Set 5 | college
# Processing Record 19 of Set 5 | ancud
# Processing Record 20 of Set 5 | langfang
# Processing Record 21 of Set 5 | olafsvik
# Processing Record 22 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 5 | kahului
# Processing Record 24 of Set 5 | rapid valley
# Processing Record 25 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 5 | new norfolk
# Processing Record 27 of Set 5 | okha
# Processing Record 28 of Set 5 | sisimiut
# Processing Record 29 of Set 5 | itarema
# Processing Record 30 of Set 5 | blairmore
# Processing Record 31 of Set 5 | shuangyashan
# Processing Record 32 of Set 5 | longyearbyen
# Processing Record 33 of Set 5 | kodinsk
# Processing Record 34 of Set 5 | sioux lookout
# Processing Record 35 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 36 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 37 of Set 5 | presidencia roque saenz pena
# Processing Record 38 of Set 5 | maningrida
# Processing Record 39 of Set 5 | brigantine
# Processing Record 40 of Set 5 | portland
# Processing Record 41 of Set 5 | georgetown
# Processing Record 42 of Set 5 | belyy yar
# Processing Record 43 of Set 5 | lompoc
# Processing Record 44 of Set 5 | mandera
# Processing Record 45 of Set 5 | mar del plata
# Processing Record 46 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 5 | mahebourg
# Processing Record 48 of Set 5 | padang
# Processing Record 49 of Set 5 | soligalich
# Processing Record 50 of Set 5 | broome
# Processing Record 1 of Set 6 | faya
# Processing Record 2 of Set 6 | ipixuna
# Processing Record 3 of Set 6 | zlobin
# Processing Record 4 of Set 6 | north bend
# Processing Record 5 of Set 6 | malakal
# Processing Record 6 of Set 6 | tapaua
# City not found. Skipping...
# Processing Record 7 of Set 6 | martvili
# Processing Record 8 of Set 6 | tawnat
# City not found. Skipping...
# Processing Record 9 of Set 6 | minot
# Processing Record 10 of Set 6 | arcachon
# Processing Record 11 of Set 6 | half moon bay
# Processing Record 12 of Set 6 | itaituba
# Processing Record 13 of Set 6 | belaya gora
# Processing Record 14 of Set 6 | esperance
# Processing Record 15 of Set 6 | eldorado
# Processing Record 16 of Set 6 | kathmandu
# Processing Record 17 of Set 6 | san jose de rio tinto
# Processing Record 18 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 6 | pevek
# Processing Record 20 of Set 6 | yashkul
# Processing Record 21 of Set 6 | kostomuksha
# Processing Record 22 of Set 6 | awbari
# Processing Record 23 of Set 6 | armidale
# Processing Record 24 of Set 6 | coquimbo
# Processing Record 25 of Set 6 | beringovskiy
# Processing Record 26 of Set 6 | alofi
# Processing Record 27 of Set 6 | saurimo
# Processing Record 28 of Set 6 | octeville
# Processing Record 29 of Set 6 | tortoli
# Processing Record 30 of Set 6 | benalla
# Processing Record 31 of Set 6 | brae
# Processing Record 32 of Set 6 | banikoara
# Processing Record 33 of Set 6 | kristianstad
# Processing Record 34 of Set 6 | fortuna
# Processing Record 35 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 36 of Set 6 | priargunsk
# Processing Record 37 of Set 6 | avera
# Processing Record 38 of Set 6 | khasan
# Processing Record 39 of Set 6 | iquique
# Processing Record 40 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 6 | bereda
# Processing Record 42 of Set 6 | taltal
# Processing Record 43 of Set 6 | baiyin
# Processing Record 44 of Set 6 | port-cartier
# Processing Record 45 of Set 6 | naze
# Processing Record 46 of Set 6 | husavik
# Processing Record 47 of Set 6 | qasigiannguit
# Processing Record 48 of Set 6 | haimen
# Processing Record 49 of Set 6 | khatanga
# Processing Record 50 of Set 6 | berezniki
# Processing Record 1 of Set 7 | yaan
# Processing Record 2 of Set 7 | malartic
# Processing Record 3 of Set 7 | ust-kalmanka
# Processing Record 4 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 7 | mattru
# Processing Record 6 of Set 7 | fairbanks
# Processing Record 7 of Set 7 | aswan
# Processing Record 8 of Set 7 | nyurba
# Processing Record 9 of Set 7 | guerrero negro
# Processing Record 10 of Set 7 | nuuk
# Processing Record 11 of Set 7 | dongsheng
# Processing Record 12 of Set 7 | lavrentiya
# Processing Record 13 of Set 7 | gizo
# Processing Record 14 of Set 7 | methoni
# Processing Record 15 of Set 7 | tonj
# Processing Record 16 of Set 7 | guaruja
# Processing Record 17 of Set 7 | urumqi
# Processing Record 18 of Set 7 | cumpas
# Processing Record 19 of Set 7 | bud
# Processing Record 20 of Set 7 | kjopsvik
# Processing Record 21 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 7 | northam
# Processing Record 23 of Set 7 | batemans bay
# Processing Record 24 of Set 7 | kruisfontein
# Processing Record 25 of Set 7 | hofn
# Processing Record 26 of Set 7 | ourem
# Processing Record 27 of Set 7 | davenda
# Processing Record 28 of Set 7 | pierre
# Processing Record 29 of Set 7 | rabat
# Processing Record 30 of Set 7 | neuquen
# Processing Record 31 of Set 7 | poum
# Processing Record 32 of Set 7 | isetskoye
# Processing Record 33 of Set 7 | susehri
# Processing Record 34 of Set 7 | conceicao do araguaia
# Processing Record 35 of Set 7 | palmer
# Processing Record 36 of Set 7 | delmas
# Processing Record 37 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 7 | hasaki
# Processing Record 39 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 7 | dzhubga
# Processing Record 41 of Set 7 | touros
# Processing Record 42 of Set 7 | nongan
# Processing Record 43 of Set 7 | tran
# Processing Record 44 of Set 7 | mehamn
# Processing Record 45 of Set 7 | muros
# Processing Record 46 of Set 7 | port macquarie
# Processing Record 47 of Set 7 | bangassou
# Processing Record 48 of Set 7 | merauke
# Processing Record 49 of Set 7 | kirensk
# Processing Record 50 of Set 7 | vostok
# Processing Record 1 of Set 8 | hirara
# Processing Record 2 of Set 8 | coihaique
# Processing Record 3 of Set 8 | jiexiu
# Processing Record 4 of Set 8 | juneau
# Processing Record 5 of Set 8 | totskoye
# Processing Record 6 of Set 8 | damghan
# Processing Record 7 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 8 of Set 8 | comodoro rivadavia
# Processing Record 9 of Set 8 | acapulco
# Processing Record 10 of Set 8 | kropotkin
# Processing Record 11 of Set 8 | lebu
# Processing Record 12 of Set 8 | inirida
# Processing Record 13 of Set 8 | monze
# Processing Record 14 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 8 | arkhara
# Processing Record 16 of Set 8 | jacareacanga
# Processing Record 17 of Set 8 | norsup
# Processing Record 18 of Set 8 | bilibino
# Processing Record 19 of Set 8 | paamiut
# Processing Record 20 of Set 8 | kuytun
# Processing Record 21 of Set 8 | rethimnon
# Processing Record 22 of Set 8 | byron bay
# Processing Record 23 of Set 8 | polyarnyy
# Processing Record 24 of Set 8 | antofagasta
# Processing Record 25 of Set 8 | caravelas
# Processing Record 26 of Set 8 | bend
# Processing Record 27 of Set 8 | tamworth
# Processing Record 28 of Set 8 | sweetwater
# Processing Record 29 of Set 8 | henties bay
# Processing Record 30 of Set 8 | provideniya
# Processing Record 31 of Set 8 | isangel
# Processing Record 32 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 8 | eureka
# Processing Record 34 of Set 8 | beloha
# Processing Record 35 of Set 8 | nkhotakota
# Processing Record 36 of Set 8 | newport
# Processing Record 37 of Set 8 | awjilah
# Processing Record 38 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 8 | bubaque
# Processing Record 40 of Set 8 | jiaonan
# Processing Record 41 of Set 8 | koslan
# Processing Record 42 of Set 8 | konevo
# Processing Record 43 of Set 8 | yar-sale
# Processing Record 44 of Set 8 | karpathos
# Processing Record 45 of Set 8 | dudinka
# Processing Record 46 of Set 8 | samsun
# Processing Record 47 of Set 8 | dayong
# Processing Record 48 of Set 8 | clyde river
# Processing Record 49 of Set 8 | tabarqah
# City not found. Skipping...
# Processing Record 50 of Set 8 | kuching
# Processing Record 1 of Set 9 | dongling
# Processing Record 2 of Set 9 | pemangkat
# Processing Record 3 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 9 | manggar
# Processing Record 5 of Set 9 | muhos
# Processing Record 6 of Set 9 | nago
# Processing Record 7 of Set 9 | hilotongan
# Processing Record 8 of Set 9 | flinders
# Processing Record 9 of Set 9 | codrington
# Processing Record 10 of Set 9 | azul
# Processing Record 11 of Set 9 | polunochnoye
# Processing Record 12 of Set 9 | bamiantong
# Processing Record 13 of Set 9 | laguna
# Processing Record 14 of Set 9 | alyangula
# Processing Record 15 of Set 9 | oktyabrskiy
# Processing Record 16 of Set 9 | harrison
# Processing Record 17 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 18 of Set 9 | galle
# Processing Record 19 of Set 9 | lashio
# Processing Record 20 of Set 9 | maunabo
# Processing Record 21 of Set 9 | vila franca do campo
# Processing Record 22 of Set 9 | ha giang
# Processing Record 23 of Set 9 | grand gaube
# Processing Record 24 of Set 9 | grand baie
# Processing Record 25 of Set 9 | iquitos
# Processing Record 26 of Set 9 | staraya russa
# Processing Record 27 of Set 9 | santa fe
# Processing Record 28 of Set 9 | lata
# Processing Record 29 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 30 of Set 9 | thunder bay
# Processing Record 31 of Set 9 | iranshahr
# Processing Record 32 of Set 9 | rafraf
# Processing Record 33 of Set 9 | oil city
# Processing Record 34 of Set 9 | florianopolis
# Processing Record 35 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 36 of Set 9 | mocuba
# Processing Record 37 of Set 9 | san juan
# Processing Record 38 of Set 9 | ahtopol
# Processing Record 39 of Set 9 | beyla
# Processing Record 40 of Set 9 | hami
# Processing Record 41 of Set 9 | chernyshevskiy
# Processing Record 42 of Set 9 | canto do buriti
# Processing Record 43 of Set 9 | oktyabrskoye
# Processing Record 44 of Set 9 | ponta do sol
# Processing Record 45 of Set 9 | eskil
# Processing Record 46 of Set 9 | cao bang
# Processing Record 47 of Set 9 | turukhansk
# Processing Record 48 of Set 9 | villa guerrero
# Processing Record 49 of Set 9 | safranbolu
# Processing Record 50 of Set 9 | briancon

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 0

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index([], dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = pd.DataFrame(city_data)

# Display sample data
city_data_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# Series([], dtype: object)

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [40], in <cell line: 5>()
#       2 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       4 # Export the city_data DataFrame into a CSV file
# ----> 5 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
#    3556     errors=errors,
#    3557     compression=compression,
#    3558     quoting=quoting,
#    3559     columns=columns,
#    3560     index_label=index_label,
#    3561     mode=mode,
#    3562     chunksize=chunksize,
#    3563     quotechar=quotechar,
#    3564     date_format=date_format,
#    3565     doublequote=doublequote,
#    3566     escapechar=escapechar,
#    3567     storage_options=storage_options,
#    3568 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1159     created_buffer = False
#    1161 csv_formatter = CSVFormatter(
#    1162     path_or_buf=path_or_buf,
#    1163     line_terminator=line_terminator,
#    (...)
#    1178     formatter=self.fmt,
#    1179 )
# -> 1180 csv_formatter.save()
#    1182 if created_buffer:
#    1183     assert isinstance(path_or_buf, StringIO)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.line_terminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:697, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     695 # Only for write methods
#     696 if "r" not in mode and is_path:
# --> 697     check_parent_directory(str(handle))
#     699 if compression:
#     700     if compression != "zstd":
#     701         # compression libraries do not like an explicit text-mode
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:571, in check_parent_directory(path)
#     569 parent = Path(path).parent
#     570 if not parent.is_dir():
# --> 571     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'Weather_Database'
