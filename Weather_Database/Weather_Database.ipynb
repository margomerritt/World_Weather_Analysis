# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 726

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")

    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]  
        city_weather_description = city_weather["weather"][0]["description"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

         
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | maloshuyka
# City not found. Skipping...
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | acapulco
# Processing Record 5 of Set 1 | chimbote
# Processing Record 6 of Set 1 | high rock
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | pangnirtung
# Processing Record 10 of Set 1 | half moon bay
# Processing Record 11 of Set 1 | nanortalik
# Processing Record 12 of Set 1 | kruisfontein
# Processing Record 13 of Set 1 | lingyuan
# Processing Record 14 of Set 1 | meulaboh
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | chokurdakh
# Processing Record 17 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | santa cruz del sur
# Processing Record 23 of Set 1 | cockburn town
# Processing Record 24 of Set 1 | adrar
# Processing Record 25 of Set 1 | khatanga
# Processing Record 26 of Set 1 | nishihara
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | yenisehir
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | uyuni
# Processing Record 31 of Set 1 | belize
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | krasnoselkup
# Processing Record 34 of Set 1 | bambous virieux
# Processing Record 35 of Set 1 | katsuura
# Processing Record 36 of Set 1 | port-gentil
# Processing Record 37 of Set 1 | clyde river
# Processing Record 38 of Set 1 | christchurch
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | antalaha
# Processing Record 42 of Set 1 | cairns
# Processing Record 43 of Set 1 | fundao
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | cherskiy
# Processing Record 46 of Set 1 | constitucion
# Processing Record 47 of Set 1 | tiksi
# Processing Record 48 of Set 1 | nouadhibou
# Processing Record 49 of Set 1 | andenes
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | gat
# Processing Record 2 of Set 2 | inhambane
# Processing Record 3 of Set 2 | yerbogachen
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | east stroudsburg
# Processing Record 7 of Set 2 | znamensk
# Processing Record 8 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 2 | asau
# Processing Record 10 of Set 2 | mae sai
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | matara
# Processing Record 13 of Set 2 | lorengau
# Processing Record 14 of Set 2 | ancud
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | cayenne
# Processing Record 17 of Set 2 | kathu
# Processing Record 18 of Set 2 | fukaya
# Processing Record 19 of Set 2 | dikson
# Processing Record 20 of Set 2 | jahrom
# City not found. Skipping...
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | port lincoln
# Processing Record 23 of Set 2 | gizo
# Processing Record 24 of Set 2 | pevek
# Processing Record 25 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | russkaya polyana
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | beringovskiy
# Processing Record 30 of Set 2 | sarany
# Processing Record 31 of Set 2 | scarborough
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | stamsund
# City not found. Skipping...
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | faya
# Processing Record 36 of Set 2 | kalmunai
# Processing Record 37 of Set 2 | sao filipe
# Processing Record 38 of Set 2 | castro
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | severo-kurilsk
# Processing Record 41 of Set 2 | hilo
# Processing Record 42 of Set 2 | vila
# Processing Record 43 of Set 2 | atasu
# Processing Record 44 of Set 2 | coihaique
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | korla
# Processing Record 47 of Set 2 | kurumoch
# Processing Record 48 of Set 2 | safaga
# Processing Record 49 of Set 2 | east london
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | guerrero negro
# Processing Record 2 of Set 3 | faanui
# Processing Record 3 of Set 3 | arraial do cabo
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | iqaluit
# Processing Record 6 of Set 3 | loei
# Processing Record 7 of Set 3 | hede
# Processing Record 8 of Set 3 | bengkulu
# Processing Record 9 of Set 3 | kahului
# Processing Record 10 of Set 3 | hobart
# Processing Record 11 of Set 3 | lebu
# Processing Record 12 of Set 3 | santa lucia
# Processing Record 13 of Set 3 | bandarbeyla
# Processing Record 14 of Set 3 | carnarvon
# Processing Record 15 of Set 3 | big rapids
# Processing Record 16 of Set 3 | huntington
# Processing Record 17 of Set 3 | san patricio
# Processing Record 18 of Set 3 | pishin
# Processing Record 19 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 3 | yanacancha
# Processing Record 21 of Set 3 | sarab
# Processing Record 22 of Set 3 | ilulissat
# Processing Record 23 of Set 3 | acarau
# Processing Record 24 of Set 3 | marl
# Processing Record 25 of Set 3 | yanam
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | hitoyoshi
# Processing Record 28 of Set 3 | omsukchan
# Processing Record 29 of Set 3 | chuy
# Processing Record 30 of Set 3 | atuona
# Processing Record 31 of Set 3 | shelopugino
# Processing Record 32 of Set 3 | ponta delgada
# Processing Record 33 of Set 3 | rio gallegos
# Processing Record 34 of Set 3 | saskylakh
# Processing Record 35 of Set 3 | roald
# Processing Record 36 of Set 3 | saint george
# Processing Record 37 of Set 3 | sinnamary
# Processing Record 38 of Set 3 | gurupa
# Processing Record 39 of Set 3 | llanes
# Processing Record 40 of Set 3 | port alfred
# Processing Record 41 of Set 3 | santa cruz cabralia
# Processing Record 42 of Set 3 | isangel
# Processing Record 43 of Set 3 | walvis bay
# Processing Record 44 of Set 3 | zhezkazgan
# Processing Record 45 of Set 3 | gazimurskiy zavod
# Processing Record 46 of Set 3 | alofi
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | pangkalanbuun
# Processing Record 49 of Set 3 | kavieng
# Processing Record 50 of Set 3 | tual
# Processing Record 1 of Set 4 | kholm-zhirkovskiy
# Processing Record 2 of Set 4 | geraldton
# Processing Record 3 of Set 4 | homer
# Processing Record 4 of Set 4 | lagoa
# Processing Record 5 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 4 | bintulu
# Processing Record 7 of Set 4 | chenzhou
# Processing Record 8 of Set 4 | lata
# Processing Record 9 of Set 4 | shirokiy
# Processing Record 10 of Set 4 | magdalena
# Processing Record 11 of Set 4 | pervomaysk
# Processing Record 12 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 4 | carballo
# Processing Record 14 of Set 4 | saint-philippe
# Processing Record 15 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 4 | avarua
# Processing Record 17 of Set 4 | belle fourche
# Processing Record 18 of Set 4 | praia
# Processing Record 19 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 4 | quimper
# Processing Record 21 of Set 4 | jujuy
# City not found. Skipping...
# Processing Record 22 of Set 4 | bridlington
# Processing Record 23 of Set 4 | tasiilaq
# Processing Record 24 of Set 4 | hasaki
# Processing Record 25 of Set 4 | araguatins
# City not found. Skipping...
# Processing Record 26 of Set 4 | nabinagar
# Processing Record 27 of Set 4 | merauke
# Processing Record 28 of Set 4 | makakilo city
# Processing Record 29 of Set 4 | sanming
# Processing Record 30 of Set 4 | voh
# Processing Record 31 of Set 4 | padang
# Processing Record 32 of Set 4 | bardiyah
# Processing Record 33 of Set 4 | clarence town
# Processing Record 34 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 36 of Set 4 | gravdal
# Processing Record 37 of Set 4 | barrhead
# Processing Record 38 of Set 4 | ingham
# Processing Record 39 of Set 4 | honiara
# Processing Record 40 of Set 4 | norman wells
# Processing Record 41 of Set 4 | meadow lake
# Processing Record 42 of Set 4 | pacific grove
# Processing Record 43 of Set 4 | sitka
# Processing Record 44 of Set 4 | isla aguada
# Processing Record 45 of Set 4 | inta
# Processing Record 46 of Set 4 | bethel
# Processing Record 47 of Set 4 | abha
# Processing Record 48 of Set 4 | kaeo
# Processing Record 49 of Set 4 | ribeira grande
# Processing Record 50 of Set 4 | pisco
# Processing Record 1 of Set 5 | esperance
# Processing Record 2 of Set 5 | kindu
# Processing Record 3 of Set 5 | bokaro
# Processing Record 4 of Set 5 | vila do maio
# Processing Record 5 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 6 of Set 5 | prince rupert
# Processing Record 7 of Set 5 | brae
# Processing Record 8 of Set 5 | ahipara
# Processing Record 9 of Set 5 | jiuquan
# Processing Record 10 of Set 5 | caravelas
# Processing Record 11 of Set 5 | chiang khong
# Processing Record 12 of Set 5 | nybro
# Processing Record 13 of Set 5 | dingle
# Processing Record 14 of Set 5 | maholi
# Processing Record 15 of Set 5 | cabo san lucas
# Processing Record 16 of Set 5 | dongkan
# Processing Record 17 of Set 5 | wajima
# Processing Record 18 of Set 5 | chavakachcheri
# Processing Record 19 of Set 5 | juneau
# Processing Record 20 of Set 5 | mamlyutka
# Processing Record 21 of Set 5 | price
# Processing Record 22 of Set 5 | itoman
# Processing Record 23 of Set 5 | vardo
# Processing Record 24 of Set 5 | byron bay
# Processing Record 25 of Set 5 | kavaratti
# Processing Record 26 of Set 5 | airai
# Processing Record 27 of Set 5 | sola
# Processing Record 28 of Set 5 | yulara
# Processing Record 29 of Set 5 | luang prabang
# Processing Record 30 of Set 5 | gornopravdinsk
# Processing Record 31 of Set 5 | banamba
# Processing Record 32 of Set 5 | alice springs
# Processing Record 33 of Set 5 | odweyne
# Processing Record 34 of Set 5 | lompoc
# Processing Record 35 of Set 5 | mackay
# Processing Record 36 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 5 | tianpeng
# Processing Record 38 of Set 5 | palma di montechiaro
# Processing Record 39 of Set 5 | bereda
# Processing Record 40 of Set 5 | ranong
# Processing Record 41 of Set 5 | balloch
# Processing Record 42 of Set 5 | wokha
# Processing Record 43 of Set 5 | juifang
# City not found. Skipping...
# Processing Record 44 of Set 5 | san pedro
# Processing Record 45 of Set 5 | kleck
# City not found. Skipping...
# Processing Record 46 of Set 5 | ostrovnoy
# Processing Record 47 of Set 5 | olafsvik
# Processing Record 48 of Set 5 | along
# Processing Record 49 of Set 5 | maues
# Processing Record 50 of Set 5 | codrington
# Processing Record 1 of Set 6 | westport
# Processing Record 2 of Set 6 | toamasina
# Processing Record 3 of Set 6 | camacha
# Processing Record 4 of Set 6 | tuatapere
# Processing Record 5 of Set 6 | toktogul
# Processing Record 6 of Set 6 | sobolevo
# Processing Record 7 of Set 6 | puerto escondido
# Processing Record 8 of Set 6 | karratha
# Processing Record 9 of Set 6 | sioux lookout
# Processing Record 10 of Set 6 | nyurba
# Processing Record 11 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 12 of Set 6 | leshukonskoye
# Processing Record 13 of Set 6 | sandpoint
# Processing Record 14 of Set 6 | el alto
# Processing Record 15 of Set 6 | berlevag
# Processing Record 16 of Set 6 | agulu
# Processing Record 17 of Set 6 | maceio
# Processing Record 18 of Set 6 | georgetown
# Processing Record 19 of Set 6 | yokadouma
# Processing Record 20 of Set 6 | madison
# Processing Record 21 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 6 | sampit
# Processing Record 23 of Set 6 | kifri
# Processing Record 24 of Set 6 | nautla
# Processing Record 25 of Set 6 | cody
# Processing Record 26 of Set 6 | moyale
# Processing Record 27 of Set 6 | potenza
# Processing Record 28 of Set 6 | hambantota
# Processing Record 29 of Set 6 | angra
# City not found. Skipping...
# Processing Record 30 of Set 6 | najran
# Processing Record 31 of Set 6 | belmonte
# Processing Record 32 of Set 6 | nantucket
# Processing Record 33 of Set 6 | linchuan
# City not found. Skipping...
# Processing Record 34 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 6 | sept-iles
# Processing Record 36 of Set 6 | thetford mines
# Processing Record 37 of Set 6 | fortuna
# Processing Record 38 of Set 6 | haveli
# Processing Record 39 of Set 6 | anadyr
# Processing Record 40 of Set 6 | port elizabeth
# Processing Record 41 of Set 6 | zhaotong
# Processing Record 42 of Set 6 | guspini
# Processing Record 43 of Set 6 | bathsheba
# Processing Record 44 of Set 6 | shonguy
# Processing Record 45 of Set 6 | aksu
# Processing Record 46 of Set 6 | palmer
# Processing Record 47 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 48 of Set 6 | uruacu
# Processing Record 49 of Set 6 | qui nhon
# Processing Record 50 of Set 6 | harstad
# Processing Record 1 of Set 7 | coquimbo
# Processing Record 2 of Set 7 | cidreira
# Processing Record 3 of Set 7 | egvekinot
# Processing Record 4 of Set 7 | kenai
# Processing Record 5 of Set 7 | mankapur
# Processing Record 6 of Set 7 | melo
# Processing Record 7 of Set 7 | auki
# Processing Record 8 of Set 7 | san cristobal
# Processing Record 9 of Set 7 | gardan diwal
# City not found. Skipping...
# Processing Record 10 of Set 7 | maryborough
# Processing Record 11 of Set 7 | longyearbyen
# Processing Record 12 of Set 7 | sidi qasim
# City not found. Skipping...
# Processing Record 13 of Set 7 | banjar
# Processing Record 14 of Set 7 | pella
# Processing Record 15 of Set 7 | upernavik
# Processing Record 16 of Set 7 | samarai
# Processing Record 17 of Set 7 | kemin
# Processing Record 18 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 19 of Set 7 | morant bay
# Processing Record 20 of Set 7 | emilio carranza
# Processing Record 21 of Set 7 | sri aman
# Processing Record 22 of Set 7 | road town
# Processing Record 23 of Set 7 | sherlovaya gora
# Processing Record 24 of Set 7 | mehamn
# Processing Record 25 of Set 7 | quatre cocos
# Processing Record 26 of Set 7 | arriana
# Processing Record 27 of Set 7 | tommot
# Processing Record 28 of Set 7 | mont-de-marsan
# Processing Record 29 of Set 7 | sfantu gheorghe
# Processing Record 30 of Set 7 | terney
# Processing Record 31 of Set 7 | sao joao da barra
# Processing Record 32 of Set 7 | klaksvik
# Processing Record 33 of Set 7 | gevrai
# Processing Record 34 of Set 7 | uray
# Processing Record 35 of Set 7 | manakara
# Processing Record 36 of Set 7 | sur
# Processing Record 37 of Set 7 | usinsk
# Processing Record 38 of Set 7 | bor
# Processing Record 39 of Set 7 | neiafu
# Processing Record 40 of Set 7 | kailua
# Processing Record 41 of Set 7 | strezhevoy
# Processing Record 42 of Set 7 | namatanai
# Processing Record 43 of Set 7 | yumen
# Processing Record 44 of Set 7 | bonfim
# Processing Record 45 of Set 7 | torbay
# Processing Record 46 of Set 7 | saldanha
# Processing Record 47 of Set 7 | lapeer
# Processing Record 48 of Set 7 | baykit
# Processing Record 49 of Set 7 | santa cruz
# Processing Record 50 of Set 7 | doboj
# Processing Record 1 of Set 8 | mazagao
# Processing Record 2 of Set 8 | mbini
# Processing Record 3 of Set 8 | oranjestad
# Processing Record 4 of Set 8 | leningradskiy
# Processing Record 5 of Set 8 | ust-maya
# Processing Record 6 of Set 8 | lavrentiya
# Processing Record 7 of Set 8 | kudahuvadhoo
# Processing Record 8 of Set 8 | sibolga
# Processing Record 9 of Set 8 | san quintin
# Processing Record 10 of Set 8 | hualmay
# Processing Record 11 of Set 8 | parry sound
# Processing Record 12 of Set 8 | luocheng
# Processing Record 13 of Set 8 | chara
# Processing Record 14 of Set 8 | foam lake
# Processing Record 15 of Set 8 | kununurra
# Processing Record 16 of Set 8 | vila franca do campo
# Processing Record 17 of Set 8 | lasa
# Processing Record 18 of Set 8 | bengbu
# Processing Record 19 of Set 8 | timon
# Processing Record 20 of Set 8 | aksay
# Processing Record 21 of Set 8 | vostok
# Processing Record 22 of Set 8 | tavricheskoye
# Processing Record 23 of Set 8 | kroya
# Processing Record 24 of Set 8 | mount isa
# Processing Record 25 of Set 8 | zonguldak
# Processing Record 26 of Set 8 | anderson
# Processing Record 27 of Set 8 | iquitos
# Processing Record 28 of Set 8 | kizilskoye
# Processing Record 29 of Set 8 | salalah
# Processing Record 30 of Set 8 | mount gambier
# Processing Record 31 of Set 8 | san luis
# Processing Record 32 of Set 8 | ambunti
# Processing Record 33 of Set 8 | roswell
# Processing Record 34 of Set 8 | nisia floresta
# Processing Record 35 of Set 8 | maniitsoq
# Processing Record 36 of Set 8 | point fortin
# Processing Record 37 of Set 8 | aklavik
# Processing Record 38 of Set 8 | alexandria
# Processing Record 39 of Set 8 | victoria
# Processing Record 40 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 8 | yongan
# Processing Record 42 of Set 8 | kisiwani
# Processing Record 43 of Set 8 | snasa
# Processing Record 44 of Set 8 | talnakh
# Processing Record 45 of Set 8 | goure
# Processing Record 46 of Set 8 | hervey bay
# Processing Record 47 of Set 8 | fort nelson
# Processing Record 48 of Set 8 | srednekolymsk
# Processing Record 49 of Set 8 | chichihualco
# Processing Record 50 of Set 8 | shenzhen
# Processing Record 1 of Set 9 | kayankulam
# Processing Record 2 of Set 9 | resistencia
# Processing Record 3 of Set 9 | daru
# Processing Record 4 of Set 9 | komsomolskiy
# Processing Record 5 of Set 9 | langsa
# Processing Record 6 of Set 9 | vanavara
# Processing Record 7 of Set 9 | marawi
# Processing Record 8 of Set 9 | helong
# Processing Record 9 of Set 9 | te anau
# Processing Record 10 of Set 9 | moose factory
# Processing Record 11 of Set 9 | turtas
# Processing Record 12 of Set 9 | el buen pastor
# City not found. Skipping...
# Processing Record 13 of Set 9 | souillac
# Processing Record 14 of Set 9 | amapa
# Processing Record 15 of Set 9 | empalme
# Processing Record 16 of Set 9 | konya
# Processing Record 17 of Set 9 | sojat
# Processing Record 18 of Set 9 | mahajanga
# Processing Record 19 of Set 9 | havelock
# Processing Record 20 of Set 9 | moses lake
# Processing Record 21 of Set 9 | haines junction
# City not found. Skipping...
# Processing Record 22 of Set 9 | anqing
# Processing Record 23 of Set 9 | hami
# Processing Record 24 of Set 9 | salinopolis
# Processing Record 25 of Set 9 | riviere-au-renard
# Processing Record 26 of Set 9 | black river
# Processing Record 27 of Set 9 | dali
# Processing Record 28 of Set 9 | blonduos
# City not found. Skipping...
# Processing Record 29 of Set 9 | aquiraz
# Processing Record 30 of Set 9 | mareeba
# Processing Record 31 of Set 9 | bato
# Processing Record 32 of Set 9 | wenling
# Processing Record 33 of Set 9 | pasighat
# Processing Record 34 of Set 9 | palmares do sul
# Processing Record 35 of Set 9 | aripuana
# Processing Record 36 of Set 9 | urumqi
# Processing Record 37 of Set 9 | tezu
# Processing Record 38 of Set 9 | panaba
# Processing Record 39 of Set 9 | iracoubo
# Processing Record 40 of Set 9 | nacala
# Processing Record 41 of Set 9 | mahebourg
# Processing Record 42 of Set 9 | pombas
# Processing Record 43 of Set 9 | da lat
# Processing Record 44 of Set 9 | dubbo
# Processing Record 45 of Set 9 | phrai bung
# City not found. Skipping...
# Processing Record 46 of Set 9 | columbus
# Processing Record 47 of Set 9 | hauterive
# Processing Record 48 of Set 9 | ust-kut
# Processing Record 49 of Set 9 | tucurui
# Processing Record 50 of Set 9 | flagstaff
# Processing Record 1 of Set 10 | pundaguitan
# Processing Record 2 of Set 10 | wahiawa
# Processing Record 3 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 10 | nome
# Processing Record 5 of Set 10 | port shepstone
# Processing Record 6 of Set 10 | digras
# Processing Record 7 of Set 10 | beyneu
# Processing Record 8 of Set 10 | poya
# Processing Record 9 of Set 10 | yar-sale
# Processing Record 10 of Set 10 | jucuaran
# Processing Record 11 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 10 | hohhot
# Processing Record 13 of Set 10 | alberton
# Processing Record 14 of Set 10 | waynesville
# Processing Record 15 of Set 10 | vilhena
# Processing Record 16 of Set 10 | ormond beach
# Processing Record 17 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 10 | port blair
# Processing Record 19 of Set 10 | sao felipe
# Processing Record 20 of Set 10 | calabar
# Processing Record 21 of Set 10 | nioro
# Processing Record 22 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 10 | diffa
# Processing Record 24 of Set 10 | majene
# Processing Record 25 of Set 10 | mattru
# Processing Record 26 of Set 10 | lianzhou
# Processing Record 27 of Set 10 | havoysund
# Processing Record 28 of Set 10 | ust-kuyga
# Processing Record 29 of Set 10 | bull savanna
# Processing Record 30 of Set 10 | sanchursk
# Processing Record 31 of Set 10 | trzebiatow
# Processing Record 32 of Set 10 | vicar
# Processing Record 33 of Set 10 | a
# City not found. Skipping...
# Processing Record 34 of Set 10 | gogrial
# Processing Record 35 of Set 10 | bobo dioulasso
# Processing Record 36 of Set 10 | hovd
# Processing Record 37 of Set 10 | kemijarvi
# Processing Record 38 of Set 10 | port hardy
# Processing Record 39 of Set 10 | smithfield
# Processing Record 40 of Set 10 | camapua
# Processing Record 41 of Set 10 | mitsamiouli
# Processing Record 42 of Set 10 | evensk
# Processing Record 43 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 44 of Set 10 | wanning
# Processing Record 45 of Set 10 | ewo
# Processing Record 46 of Set 10 | misratah
# Processing Record 47 of Set 10 | lewistown
# Processing Record 48 of Set 10 | krasnoturansk
# Processing Record 49 of Set 10 | bubaque
# Processing Record 50 of Set 10 | vila velha
# Processing Record 1 of Set 11 | dunedin
# Processing Record 2 of Set 11 | rocha
# Processing Record 3 of Set 11 | harlingen
# Processing Record 4 of Set 11 | council bluffs
# Processing Record 5 of Set 11 | lavumisa
# Processing Record 6 of Set 11 | rio grande
# Processing Record 7 of Set 11 | arlit
# Processing Record 8 of Set 11 | camacupa
# Processing Record 9 of Set 11 | agadir
# Processing Record 10 of Set 11 | husavik
# Processing Record 11 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 11 | malakal
# Processing Record 13 of Set 11 | springbok
# Processing Record 14 of Set 11 | borovskoy
# Processing Record 15 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 11 | el retorno
# Processing Record 17 of Set 11 | sulaco
# Processing Record 18 of Set 11 | suntar
# Processing Record 19 of Set 11 | ugoofaaru
# Processing Record 20 of Set 11 | kudchi
# City not found. Skipping...
# Processing Record 21 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 11 | balimo
# City not found. Skipping...
# Processing Record 23 of Set 11 | moron
# Processing Record 24 of Set 11 | raahe
# Processing Record 25 of Set 11 | vangaindrano
# Processing Record 26 of Set 11 | joniskis
# Processing Record 27 of Set 11 | thinadhoo
# Processing Record 28 of Set 11 | viedma
# Processing Record 29 of Set 11 | urulga
# City not found. Skipping...
# Processing Record 30 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 11 | alekseyevka
# Processing Record 33 of Set 11 | svetlogorsk
# Processing Record 34 of Set 11 | ipixuna
# Processing Record 35 of Set 11 | athabasca
# Processing Record 36 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 11 | stornoway
# Processing Record 38 of Set 11 | bassano
# Processing Record 39 of Set 11 | arroyo
# Processing Record 40 of Set 11 | joao pessoa
# Processing Record 41 of Set 11 | barcelos
# Processing Record 42 of Set 11 | laela
# Processing Record 43 of Set 11 | groningen
# Processing Record 44 of Set 11 | calamar
# Processing Record 45 of Set 11 | pangobilian
# Processing Record 46 of Set 11 | raudeberg
# Processing Record 47 of Set 11 | careiro da varzea
# Processing Record 48 of Set 11 | zaraysk
# Processing Record 49 of Set 11 | utiel
# Processing Record 50 of Set 11 | vanimo
# Processing Record 1 of Set 12 | ixtapa
# Processing Record 2 of Set 12 | donduseni
# Processing Record 3 of Set 12 | yuyao
# Processing Record 4 of Set 12 | praia da vitoria
# Processing Record 5 of Set 12 | richards bay
# Processing Record 6 of Set 12 | osuna
# Processing Record 7 of Set 12 | lixourion
# Processing Record 8 of Set 12 | pavlodar
# Processing Record 9 of Set 12 | rovaniemi
# Processing Record 10 of Set 12 | villa carlos paz
# Processing Record 11 of Set 12 | dakar
# Processing Record 12 of Set 12 | uva
# Processing Record 13 of Set 12 | bambanglipuro
# Processing Record 14 of Set 12 | gold coast
# Processing Record 15 of Set 12 | camocim
# Processing Record 16 of Set 12 | prestea
# Processing Record 17 of Set 12 | bolobo
# Processing Record 18 of Set 12 | salaga
# Processing Record 19 of Set 12 | agirish
# Processing Record 20 of Set 12 | channel-port aux basques
# Processing Record 21 of Set 12 | esna
# Processing Record 22 of Set 12 | anjiang
# Processing Record 23 of Set 12 | sao felix do xingu
# Processing Record 24 of Set 12 | san jeronimo
# Processing Record 25 of Set 12 | kursenai
# Processing Record 26 of Set 12 | kirakira
# Processing Record 27 of Set 12 | scheemda
# Processing Record 28 of Set 12 | port augusta
# Processing Record 29 of Set 12 | nalut
# Processing Record 30 of Set 12 | dzhebariki-khaya
# Processing Record 31 of Set 12 | laukaa
# Processing Record 32 of Set 12 | rapid city
# Processing Record 33 of Set 12 | plougastel-daoulas
# Processing Record 34 of Set 12 | tomaszow mazowiecki
# Processing Record 35 of Set 12 | obo
# Processing Record 36 of Set 12 | porbandar
# Processing Record 37 of Set 12 | swift current
# Processing Record 38 of Set 12 | warburton
# Processing Record 39 of Set 12 | buraydah
# Processing Record 40 of Set 12 | sorland
# Processing Record 41 of Set 12 | karpathos
# Processing Record 42 of Set 12 | portland
# Processing Record 43 of Set 12 | rawson
# Processing Record 44 of Set 12 | zyryanka
# Processing Record 45 of Set 12 | novoagansk
# Processing Record 46 of Set 12 | nelson bay
# Processing Record 47 of Set 12 | lahij
# Processing Record 48 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 12 | storforshei
# Processing Record 50 of Set 12 | stephenville crossing
# Processing Record 1 of Set 13 | burica
# City not found. Skipping...
# Processing Record 2 of Set 13 | revadanda
# Processing Record 3 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 13 | mendoza
# Processing Record 5 of Set 13 | tucuma
# Processing Record 6 of Set 13 | saint-donat-de-montcalm
# Processing Record 7 of Set 13 | grindavik
# Processing Record 8 of Set 13 | inirida
# Processing Record 9 of Set 13 | naze
# Processing Record 10 of Set 13 | anshun
# Processing Record 11 of Set 13 | sharjah
# Processing Record 12 of Set 13 | cheney
# Processing Record 13 of Set 13 | turukhansk
# Processing Record 14 of Set 13 | porto walter
# Processing Record 15 of Set 13 | preobrazheniye
# Processing Record 16 of Set 13 | tahta
# Processing Record 17 of Set 13 | plainview
# Processing Record 18 of Set 13 | azar shahr
# City not found. Skipping...
# Processing Record 19 of Set 13 | tuy hoa
# Processing Record 20 of Set 13 | lokosovo
# Processing Record 21 of Set 13 | necochea
# Processing Record 22 of Set 13 | stromness
# Processing Record 23 of Set 13 | kinshasa
# Processing Record 24 of Set 13 | san mateo ixtatan
# Processing Record 25 of Set 13 | le havre
# Processing Record 26 of Set 13 | manzanillo
# Processing Record 27 of Set 13 | santa marta
# Processing Record 28 of Set 13 | mana
# Processing Record 29 of Set 13 | charters towers
# Processing Record 30 of Set 13 | ratnagiri
# Processing Record 31 of Set 13 | maumere
# Processing Record 32 of Set 13 | kangaatsiaq
# Processing Record 33 of Set 13 | chicama
# Processing Record 34 of Set 13 | nushki
# Processing Record 35 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 36 of Set 13 | jining
# Processing Record 37 of Set 13 | college
# Processing Record 38 of Set 13 | sisimiut
# Processing Record 39 of Set 13 | ossora
# Processing Record 40 of Set 13 | statesville
# Processing Record 41 of Set 13 | kamenka
# Processing Record 42 of Set 13 | kamaishi
# Processing Record 43 of Set 13 | ternate
# Processing Record 44 of Set 13 | dalby
# Processing Record 45 of Set 13 | hobyo
# Processing Record 46 of Set 13 | luderitz
# Processing Record 47 of Set 13 | parit buntar
# Processing Record 48 of Set 13 | kankon
# Processing Record 49 of Set 13 | bhatkal
# Processing Record 50 of Set 13 | tazovskiy
# Processing Record 1 of Set 14 | linxia
# Processing Record 2 of Set 14 | aykhal
# Processing Record 3 of Set 14 | constantine
# Processing Record 4 of Set 14 | katobu
# Processing Record 5 of Set 14 | ashqelon
# Processing Record 6 of Set 14 | atikokan
# Processing Record 7 of Set 14 | toora-khem
# Processing Record 8 of Set 14 | altamont
# Processing Record 9 of Set 14 | shingu
# Processing Record 10 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 11 of Set 14 | carroll
# Processing Record 12 of Set 14 | kieta
# Processing Record 13 of Set 14 | la ronge
# Processing Record 14 of Set 14 | jala
# Processing Record 15 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 16 of Set 14 | beya
# Processing Record 17 of Set 14 | pamulang
# Processing Record 18 of Set 14 | coruripe
# Processing Record 19 of Set 14 | tateyama
# Processing Record 20 of Set 14 | muravlenko
# Processing Record 21 of Set 14 | mumford
# Processing Record 22 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 24 of Set 14 | kalabo
# Processing Record 25 of Set 14 | shamary
# Processing Record 26 of Set 14 | victor harbor
# Processing Record 27 of Set 14 | alyangula
# Processing Record 28 of Set 14 | waddan
# Processing Record 29 of Set 14 | namibe
# Processing Record 30 of Set 14 | ca mau
# Processing Record 31 of Set 14 | san pedro buenavista
# Processing Record 32 of Set 14 | zaria
# Processing Record 33 of Set 14 | reinosa
# Processing Record 34 of Set 14 | ginir
# Processing Record 35 of Set 14 | zhigansk
# Processing Record 36 of Set 14 | valley city
# Processing Record 37 of Set 14 | soyo
# Processing Record 38 of Set 14 | voyvozh
# Processing Record 39 of Set 14 | cajnice
# Processing Record 40 of Set 14 | tutoia
# Processing Record 41 of Set 14 | teguise
# Processing Record 42 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 43 of Set 14 | la asuncion
# Processing Record 44 of Set 14 | areosa
# Processing Record 45 of Set 14 | zharkent
# Processing Record 46 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 47 of Set 14 | saint-pierre
# Processing Record 48 of Set 14 | sandy bay
# Processing Record 49 of Set 14 | eureka
# Processing Record 50 of Set 14 | pimentel
# Processing Record 1 of Set 15 | tura
# Processing Record 2 of Set 15 | duxbury
# Processing Record 3 of Set 15 | kundiawa
# Processing Record 4 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 15 | chapais
# Processing Record 6 of Set 15 | lincoln
# Processing Record 7 of Set 15 | yagoua
# Processing Record 8 of Set 15 | plettenberg bay
# Processing Record 9 of Set 15 | trelew
# Processing Record 10 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 15 | deputatskiy
# Processing Record 12 of Set 15 | tynda
# Processing Record 13 of Set 15 | struga
# Processing Record 14 of Set 15 | elze
# Processing Record 15 of Set 15 | sinnai
# Processing Record 16 of Set 15 | comodoro rivadavia
# Processing Record 17 of Set 15 | karacakoy
# Processing Record 18 of Set 15 | waipawa
# Processing Record 19 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 20 of Set 15 | touros
# Processing Record 21 of Set 15 | araouane
# Processing Record 22 of Set 15 | fredericksburg
# Processing Record 23 of Set 15 | garden city
# Processing Record 24 of Set 15 | leh
# Processing Record 25 of Set 15 | doha
# Processing Record 26 of Set 15 | tarakan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 662

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ushuaia -54.8000  -68.3000     44.26        61          40
# 1       Acapulco  16.8634  -99.8901     82.08        76          16
# 2       Chimbote  -9.0853  -78.5783     64.24        83          46
# 3      High Rock  26.6208  -78.2833     75.22        91         100
# 4      Busselton -33.6500  115.3333     61.20        83          95
# 5        Rikitea -23.1203 -134.9692     73.31        86         100
# 6    Pangnirtung  66.1451  -65.7125      2.48        95         100
# 7  Half Moon Bay  37.4636 -122.4286     61.05        63           0
# 8     Nanortalik  60.1432  -45.2371     32.13        80         100
# 9   Kruisfontein -34.0033   24.7314     56.88        78          76
#
#    Wind Speed Country                 Date Current Description
# 0       18.41      AR  2022-11-09 22:59:40    scattered clouds
# 1        9.51      MX  2022-11-09 23:00:09          few clouds
# 2        9.17      PE  2022-11-09 23:00:10    scattered clouds
# 3       33.93      BS  2022-11-09 23:00:10     overcast clouds
# 4        7.34      AU  2022-11-09 23:00:11          light rain
# 5        9.44      PF  2022-11-09 23:00:12     overcast clouds
# 6        1.83      CA  2022-11-09 23:00:12     overcast clouds
# 7       20.71      US  2022-11-09 23:00:13           clear sky
# 8        4.03      GL  2022-11-09 23:00:13     overcast clouds
# 9        2.57      ZA  2022-11-09 23:00:14          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ushuaia      AR -54.8000  -68.3000     44.26        61          40
# 1       Acapulco      MX  16.8634  -99.8901     82.08        76          16
# 2       Chimbote      PE  -9.0853  -78.5783     64.24        83          46
# 3      High Rock      BS  26.6208  -78.2833     75.22        91         100
# 4      Busselton      AU -33.6500  115.3333     61.20        83          95
# 5        Rikitea      PF -23.1203 -134.9692     73.31        86         100
# 6    Pangnirtung      CA  66.1451  -65.7125      2.48        95         100
# 7  Half Moon Bay      US  37.4636 -122.4286     61.05        63           0
# 8     Nanortalik      GL  60.1432  -45.2371     32.13        80         100
# 9   Kruisfontein      ZA -34.0033   24.7314     56.88        78          76
#
#    Wind Speed Current Description
# 0       18.41    scattered clouds
# 1        9.51          few clouds
# 2        9.17    scattered clouds
# 3       33.93     overcast clouds
# 4        7.34          light rain
# 5        9.44     overcast clouds
# 6        1.83     overcast clouds
# 7       20.71           clear sky
# 8        4.03     overcast clouds
# 9        2.57          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index=False)
